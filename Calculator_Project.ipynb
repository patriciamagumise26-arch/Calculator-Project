# %%
def add(x,y):
    return x + y

def substract(x,y):
    return x - y

def multiply(x,y):
    return x * y

def divide(x,y):
    return x  / y

# %%
choice = input('Enter Choice (A,S,M,D):')
# Out:
# Enter Choice (A,S,M,D):D

# %%
print ("Enter 'A' for Addition")
print ("Enter 'S' for Substraction")
print ("Enter 'M' for Multiplication")
print ("Enter 'D' for Division")


while True:
  choice = input('Enter Choice (A,S,M,D):')

  if choice.upper() in ('A','ADD','ADDITION','S','SUBSTRACT','SUBSTRACTION','M', 'MULTIPLY','MULTIPLICATION','D','DIVIDE','DIVISION'):
      num1= float(input('Enter first number:'))
      num2=  float(input('Enter second number:'))

      if choice.upper() in ('A','ADD','ADDITION'):
          print('Result:', num1,'+', num2,'=', add(num1,num2))

      elif choice.upper() in ('S','SUBSTRACT','SUBSTRACTION'):
          print('Result:',num1,'-', num2,'=', substract(num1,num2))

      elif choice.upper() in ('M', 'MULTIPLY','MULTIPLICATION'):
          print('Result:',num1,'*', num2,'=', multiply(num1,num2))

      elif choice.upper() in ('D','DIVIDE','DIVISION'):
          print('Result:',num1,'/', num2,'=', divide(num1,num2))

      next_calculation = input("Want to do next calculation? (yes/no): ")
      if next_calculation.lower() == "no":
          break
  else:
      print('Invalid, please input a correct choice')
# Out:
# Enter 'A' for Addition
# Enter 'S' for Substraction
# Enter 'M' for Multiplication
# Enter 'D' for Division

# %%
import os
print(os.listdir('.'))
